# %% [markdown]
# <a href="https://colab.research.google.com/github/p-netizen-ds/100-days-of-python/blob/main/Data_Types%2C_Variables_and_I_O(DAY%201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I am learning Python

# %%
print("3000")
# Out:
# 3000

# %%
print("Ishan")
# Out:
# Ishan

# %%
print(1+3)
# Out:
# 4

# %%
print(8-5)
# Out:
# 3

# %%
Print(8-5) # p is not equal to P
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3978011808.py in <cell line: 0>()
# ----> 1 Print(8-5) # p is not equal to P
#
# NameError: name 'Print' is not defined

# %%
print("8-5")
# Out:
# 8-5

# %%
# finding the type of a variable

type(.2)
# Out:
# float

# %%
type("3.14")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(3000)
# Out:
# int

# %%
type(None)
# Out:
# NoneType

# %%
type(1+2)
# Out:
# int

# %%
"24/10/2014"
# Out:
# '24/10/2014'

# %% [markdown]
# Variables

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a = 15
a = 0
print(a)
# Out:
# 0

# %%
type(a)
# Out:
# int

# %%
b = 5

# %%
print(a+b) # print(0 + 5)
# Out:
# 5

# %%
print(a,b,9)
# Out:
# 0 5 9

# %%
print("Hello",   "World", "!")
# Out:
# Hello World !

# %%
a = "Hello"
b = "World!"

# %%
print(a,b)
# Out:
# Hello World!

# %%
c = a+b

# %%
c
# Out:
# 'HelloWorld!'

# %%
print(c)
# Out:
# HelloWorld!

# %%
1_var_name = 5
# Out:
#   File "/tmp/ipython-input-2183908813.py", line 1
#     1_var_name = 5
#      ^
# SyntaxError: invalid decimal literal

# %%
a*b*c = 10
# Out:
#   File "/tmp/ipython-input-408818972.py", line 1
#     a*b*c = 10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Taking user input

# %%
# input() - always takes the input as string

name = input("Enter your name:")
# Out:
# Enter your name:Shubh

# %%
print(name)
# Out:
# Shubh

# %%
type(name)
# Out:
# str

# %%
print("Hello", name)
# Out:
# Hello Shubh

# %%
x = 5
y = "shubh"
x = 10
z = y
print(x,z)
# Out:
# 10 shubh

# %%
x = 3
y = 'hello'
num = y # hello
y = 5
print(num, y)
# Out:
# hello 5

# %%
x = input()
y = input()
# Out:
# 5
# 7

# %%
print(x+y)
# Out:
# 57

# %%
x = int(input())
y = int(input())
# Out:
# 5
# 7

# %%
print(x+y)
# Out:
# 12

# %%
x = input()
y = input()

int_x = int(x)
int_y = int(y)

print(int_x+int_y)
# Out:
# 5
# 7
# 12

# %%
print(int(x)+int(y))
# Out:
# 12

# %%
print(int_x+int_y)
# Out:
# 12

# %%
print(x)
print(y)
# Out:
# 5
# 7
