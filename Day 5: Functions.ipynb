# %% [markdown]
# <a href="https://colab.research.google.com/github/ishan-phadnis24/100-days-of-python/blob/main/Day%205%3A%20Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Functions: basics

# %%
def guests_coming_home ():
  print("bring food")
  print("bring water")
  print("CLean house")

# %%
guests_coming_home()
# Out:
# bring food
# bring water
# CLean house

# %%
def make_tea():
  print("Make tea")

# %%
for i in range(5):
  make_tea()
# Out:
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea

# %%
def make_tea1(N):
  for i in range(N):
    print("Make tea")

# %%
N = int(input())

make_tea1(N)
# Out:
# 8
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea

# %%
def family(father,mother,sibling):
  print('father:',father)
  print('mother:', mother)
  print('sibling:', sibling)

# %%
family("Jon",'marry','sid')
# Out:
# father: Jon
# mother: marry
# sibling: sid

# %%
family("A","C","B") #positional arguments
# Out:
# father: A
# mother: C
# sibling: B

# %%
family("A",sibling="C",mother = "B")#keyword arguments
# Out:
# father: A
# mother: B
# sibling: C

# %%
def make_coffe(num):
  for i in range (num):
                  print("I'm making coffee")

# %%
make_coffe(5)
# Out:
# I'm making coffee
# I'm making coffee
# I'm making coffee
# I'm making coffee
# I'm making coffee

# %%
#return

def fun_p():
  print(5)

# %%
num = fun_p()
# Out:
# 5

# %%
num#no output cuz print

# %%
def fun_r():
  return 5

# %%
num1 = fun_r()

# %%
num1#output cuz return
# Out:
# 5

# %%
def do_something(n):
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1
    return total

print(do_something(5))
# Out:
# 15

# %%
def simple_interest(p,t,r=8):#r is a default argument
  print(p,t,r)#default arg always at the end
  return(p*t*r)/100

# %%
simple_interest(1000,5)
# Out:
# 1000 5 8
# 400.0
