# %% [markdown]
# <a href="https://colab.research.google.com/github/ishan-phadnis24/100-days-of-python/blob/main/Day%205%3A%20Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Functions: basics

# %%
def guests_coming_home ():
  print("bring food")
  print("bring water")
  print("CLean house")

# %%
guests_coming_home()
# Out:
# bring food
# bring water
# CLean house

# %%
def make_tea():
  print("Make tea")

# %%
for i in range(5):
  make_tea()
# Out:
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea

# %%
def make_tea1(N):
  for i in range(N):
    print("Make tea")

# %%
N = int(input())

make_tea1(N)
# Out:
# 8
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea
# Make tea

# %%
def family(father,mother,sibling):
  print('father:',father)
  print('mother:', mother)
  print('sibling:', sibling)

# %%
family("Jon",'marry','sid')
# Out:
# father: Jon
# mother: marry
# sibling: sid

# %%
family("A","C","B") #positional arguments
# Out:
# father: A
# mother: C
# sibling: B

# %%
family("A",sibling="C",mother = "B")#keyword arguments
# Out:
# father: A
# mother: B
# sibling: C

# %%
def make_coffe(num):
  for i in range (num):
                  print("I'm making coffee")

# %%
make_coffe(5)
# Out:
# I'm making coffee
# I'm making coffee
# I'm making coffee
# I'm making coffee
# I'm making coffee

# %%
#return

def fun_p():
  print(5)

# %%
num = fun_p()
# Out:
# 5

# %%
num#no output cuz print

# %%
def fun_r():
  return 5

# %%
num1 = fun_r()

# %%
num1#output cuz return
# Out:
# 5

# %%
def do_something(n):
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1
    return total

print(do_something(5))
# Out:
# 15

# %%
def simple_interest(p,t,r=8):#r is a default argument
  print(p,t,r)#default arg always at the end
  return(p*t*r)/100

# %%
simple_interest(1000,5)
# Out:
# 1000 5 8
# 400.0

# %%
#scope of variables
#num = 5#global
def func_var(num):
  num = 3#local

  print(num)

func_var(num)
print(num)
# Out:
# 3
# 5

# %%
func_var(num)
print(num)
# Out:
# 3
# 5

# %%
def func_var(num):
  num = 3#local

  print(num)

func_var(num)
print(num)
# Out:
# 3
# 5

# %%
'''Write a program that takes the cost price of a vehicle as an argument and returns the road tax,
 that the vehicle owner has to pay according to the following criteria:


Note1: Return the tax up to one decimal place. You can use round(tax,1)

Note2: You need not take input in this problem, you need to only implement the function provided.

'''

def road_tax(cost_price):
    if cost_price <= 50000:
        return round(cost_price * 5 / 100, 1)
    elif cost_price <= 75000:
        return round(cost_price * 10 / 100, 1)
    elif cost_price <= 100000:
        return round(cost_price * 15 / 100, 1)
    else:
        return round(cost_price * 20 / 100, 1)

# %%
#Given an integer n, write a program to return the sum of squares of first n natural numbers in integer format.
#Note1:
#The formula for the sum of squares of first n natural numbers is: n(n+1)(2n+1)/6
def sum_of_squares(n):
  ans = n*(n+1)*((2*n)+1)//6
  return ans

# %%
sum_of_squares(5)
# Out:
# 55

# %%
x = "global"
def foo():
    global x
    print(x, end=",")
    x = "local"
    print(x, end=",")

foo()
print(x, end="")
# Out:
# global,local,local

# %%
N = 5
for i in range(1,N+1):
    print(i,end=" ")
# Out:
# 1 2 3 4 5

# %%
N = 5
for i in range(N,0,-1):
  print(i, end=" ")
# Out:
# 5 4 3 2 1

# %%
def g(N):
  for i in range(1,N+1):
    print(i,end =" ")
  print()
  for i in range(N,0,-1):
    print(i, end=" ")

# %%
g(5)
# Out:
# 1 2 3 4 5
# 5 4 3 2 1

# %%
x = 55
def hi():
  return x
x +=10
print(hi())
# Out:
# 65

# %%
#Q what is the output?

def function(var):
    print(var)

function(3)# prints once

var = 5
function(var)#prints with new value


'''
3
5
'''
# Out:
# 3
# 5
# '\n3\n5\n'

# %%
'''
Write a function to check whether a given number n as an input to the function is a perfect number or not.

 If the given integer is a perfect number return 1 else return 0.

Note: In number theory, a perfect number is a positive integer that is equal to the sum of its proper positive divisors, that is,
 the sum of its positive divisors excluding the number itself (also known as its aliquot sum).
'''
def is_perfect(n):
    divisor_sum = 0
    for i in range(1, n):
        if n % i == 0:
            divisor_sum += i
    return 1 if divisor_sum == n else 0

# %%
'''
Problem Description:

You are given a positive integer r denoting the radius of a sphere as a parameter.
 Write a program to calculate the volume of the sphere. The volume of a sphere having radius R is given by (4 * π * R3) / 3.

NOTE: Return the volume of the sphere up to two decimal places. You can use round().

NOTE2: Use pi as 22/7 (not math.pi).
'''
def sphere_volume(r):
  pi = 22/7
  volume = (4*pi*r**3)/3
  return round(volume,2)

# %%
'''
You are given a lowercase latin alphabetic character C. You have to tell whether it is a vowel or not.

The characters 'a', 'e', 'i', 'o', and 'u' are called vowels.

Note: You just have to write the code inside the function and return the result. The input and output is handled in the backend.
'''

def isvowel(C):
    vowel = ("a","e","i","o","u")
    if C in vowel:
        return 1
    else:
        return 0

# %%
'''iven the temperature of a day in Degrees Celsius, convert this given temperature from Celsius to Fahrenheit.
Complete the function to do so.
Round the output up to 2 decimal places
'''

def celsius_farhen(Celsius):
    Farenhiet = (9/5 * Celsius) + 32


    return round(Farenhiet,2)

# %%
n= 8
print("*" * n)
for i in range(1, n - 1):
        spaces = n - i - 2
        print('*' + ' ' * spaces + '*')
# Out:
# ********
# *     *
# *    *
# *   *
# *  *
# * *
# **

# %%
#lambda functions


#lambda argumets: expression

(lambda x :x*x)(4)
# Out:
# 16

# %%
(lambda x,y : x+y)(4,2)
# Out:
# 6

# %%
a = int(input())
b = int(input())
# Out:
# 8
# 1

# %%
(lambda x, y : x//y)(a,b)
# Out:
# 8

# %%
(lambda : print("Ishan Phadnis, AI engineer@FAANG"))()
# Out:
# Ishan Phadnis, AI engineer@FAANG

# %%
def process_data(a, b=10):
   return a * b

x = 5
y = 20

result1 = process_data(x)           # Pass 'x' as positional argument
result2 = process_data(a=y)         # Pass 'y' as keyword argument
result3 = process_data(a=x, b=y)    # Pass both 'x' and 'y' as positional/keyword arguments

result1, result2, result3
# Out:
# (50, 200, 100)

# %%
u = int(input())  # urgency: 1 (low), 2 (medium), 3 (high)
i = int(input())  # importance: 1 (low), 2 (medium), 3 (high)

if u == 3:
    if i == 3:
        print("Critical")
    elif i == 2:
        print("High")
    elif i == 1:
        print("Moderate")
elif u == 2:
    if i == 3:
        print("High")
    elif i == 2:
        print("Medium")
    elif i == 1:
        print("Moderate")
else:
    if i == 3:
        print("Medium")
    elif i == 2:
        print("Low")
    else:
        print("Trivial")
# Out:
# 2
# 1
# Moderate

# %%
   attempts = int(input("Attempts: "))
access_level = int(input("Level (1-Guest, 2-User, 3-Admin): "))

# 1. Check the 'Override' rule first
if attempts > 5:
    print("Security Alert")

# 2. Check the specific 'New Session' rule
elif attempts == 0 and (access_level == 2 or access_level == 3):
    print("New Session")

# 3. Check Admin access
elif attempts <= 3 and access_level == 3:
    print("Welcome, Admin")

# 4. Check Denied Access for Guests
elif attempts > 3 and access_level == 1:
    print("Access Denied")
# Out:
# Attempts: 3
# Level (1-Guest, 2-User, 3-Admin): 3
# Welcome, Admin

# %%
def process_data(a, b=10):
   return a * b

x = 5
y = 20

result1 = process_data(x)           # Pass 'x' as positional argument
result2 = process_data(a=y)         # Pass 'y' as keyword argument
result3 = process_data(a=x, b=y)    # Pass both 'x' and 'y' as positional/keyword arguments

result1, result2, result3
# Out:
# (50, 200, 100)
